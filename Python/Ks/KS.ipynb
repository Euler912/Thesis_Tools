# %% [markdown]
# <a href="https://colab.research.google.com/github/Euler912/Thesis_Tools/blob/main/KS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define convex functions
f1 = lambda x: x**2      # Quadratic function
f2 = lambda x: np.exp(x)  # Exponential function
f3 = lambda x: np.abs(x)  # Absolute value (convex)
f4 = lambda x: np.log(1 + x**2)  # Log-squared function (convex)

functions = [f1, f2, f3, f4]  # List of convex functions
p = 3
x = np.linspace(-2, 2, 100)

# Compute KS aggregation
ks_values = KS(functions, x, p)
max_values = np.maximum.reduce([func(x) for func in functions])  # Max of functions

# Plot results
plt.figure(figsize=(8,5))
plt.plot(x, ks_values, label='KS Aggregation', linewidth=2, color='orange')
plt.plot(x, max_values, label='Max Function', linewidth=2, color='blue', linestyle='dashed')

# Plot individual convex functions
for i, func in enumerate(functions):
    plt.plot(x, func(x), linestyle='dotted', label=f'f{i+1}(x)', alpha=0.7)

plt.legend()
plt.xlabel('x')
plt.ylabel('Function Value')
plt.title(f'KS Aggregation and Max Function with p={p}')
plt.grid(True)
plt.show()
